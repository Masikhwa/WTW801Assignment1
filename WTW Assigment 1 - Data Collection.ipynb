# %%
# Downloads JSE prices from Yahoo, prepares "Total Return" proxies & returns, saves files, and makes a check plot.
from pathlib import Path
from datetime import date
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# ---------- CONFIG ----------
START = "1998-01-01"     # ensures >1000 daily obs
END = None               # None = up to today
OUTDIR = Path("data")
PLOT_ASSETS = ["NPN.JO", "MTN.JO", "SOL.JO"]  # any 3 you want to show

TICKERS = {
    "ABG.JO": "Absa Group Ltd",
    "SBK.JO": "Standard Bank Group Ltd",
    "FSR.JO": "FirstRand Ltd",
    "SLM.JO": "Sanlam Ltd",
    "SOL.JO": "Sasol Ltd",
    "SHP.JO": "Shoprite Holdings Ltd",
    "WHL.JO": "Woolworths Holdings Ltd",
    "MRP.JO": "Mr Price Group Ltd",
    "BVT.JO": "Bidvest Group Ltd",
    "GFI.JO": "Gold Fields Ltd",
    "NED.JO": "Nedbank Group Ltd",
    "INL.JO": "Investec Ltd",
    "CLS.JO": "Clicks Group Ltd",
    "GRT.JO": "Growthpoint Properties Ltd",
    "MTN.JO": "MTN Group Ltd",
    "IMP.JO": "Impala Platinum Holdings Ltd",
    "NPN.JO": "Naspers Ltd (N Shares)",
    "CFR.JO": "Compagnie Financière Richemont SA",
    "HAR.JO": "Harmony Gold Mining Company Ltd",
    "APN.JO": "Aspen Pharmacare Holdings Ltd",
}

# Convenience: list of tickers in stable order (e.g., for loops / downloads)
TICKER_LIST = list(TICKERS.keys())

def main():
    OUTDIR.mkdir(parents=True, exist_ok=True)

    # 1) Download daily adjusted data (auto_adjust=True gives dividend & split adjusted OHLC)
    df_raw = yf.download(
        TICKER_LIST,
        start=START,
        end=END,
        interval="1d",
        auto_adjust=True,
        group_by="ticker",
        threads=True,
        progress=False,
    )

    # 2) Extract adjusted closing prices (with auto_adjust=True, 'Close' is adjusted)
    # df_raw has a MultiIndex of (ticker, field). We take the 'Close' slice.
    close = df_raw.xs("Close", axis=1, level=1).sort_index()
    close = close.loc[~close.index.duplicated(keep="first")]  # just in case
    close = close.dropna(how="all")  # drop rows where all tickers are NaN

    # Drop tickers that completely failed to download
    non_empty_cols = [c for c in close.columns if close[c].dropna().shape[0] > 0]
    close = close[non_empty_cols]

    # 3) Build a "Total Return" index proxy by rebasing adjusted close to 100
    tri = (close / close.iloc[0]) * 100.0

    # 4) Compute returns
    returns = close.pct_change().dropna()       # simple returns r_t = (I_t - I_{t-1}) / I_{t-1}
    logrets = np.log(close).diff().dropna()     # log returns

    # 5) Basic sanity checks
    print(f"Universe downloaded: {list(close.columns)}")
    print(f"Observations: prices={len(close):,}, returns={len(returns):,}")

    # 6) Save tidy files for the assignment
    close.to_parquet(OUTDIR / "jse_prices_adjclose.parquet")
    returns.to_parquet(OUTDIR / "jse_returns_simple.parquet")
    logrets.to_parquet(OUTDIR / "jse_returns_log.parquet")
    tri.to_parquet(OUTDIR / "jse_total_return_index_rebased100.parquet")

    close.to_csv(OUTDIR / "jse_prices_adjclose.csv", index=True)
    returns.to_csv(OUTDIR / "jse_returns_simple.csv", index=True)
    logrets.to_csv(OUTDIR / "jse_returns_log.csv", index=True)
    tri.to_csv(OUTDIR / "jse_total_return_index_rebased100.csv", index=True)

    # 7) Plot: “Total Return” proxy for three assets (satisfies Q1 plotting requirement)
    to_plot = [t for t in PLOT_ASSETS if t in tri.columns][:3]
    ax = tri[to_plot].plot(figsize=(10, 6), lw=1.7)
    ax.set_title("JSE: Total Return (Adj Close rebased to 100)")
    ax.set_ylabel("Index (100 = first date)")
    ax.set_xlabel("Date")
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # 8) Optional: weekly/monthly variants (uncomment if you want different frequencies)
    # close_w = close.resample("W-FRI").last()
    # close_m = close.resample("M").last()
    # close_w.to_parquet(OUTDIR / "jse_prices_adjclose_weekly.parquet")
    # close_m.to_parquet(OUTDIR / "jse_prices_adjclose_monthly.parquet")

if __name__ == "__main__":
    main()
# Out:
# Universe downloaded: ['CFR.JO', 'GRT.JO', 'BVT.JO', 'SLM.JO', 'HAR.JO', 'MTN.JO', 'MRP.JO', 'WHL.JO', 'APN.JO', 'GFI.JO', 'SHP.JO', 'SBK.JO', 'IMP.JO', 'FSR.JO', 'ABG.JO', 'SOL.JO', 'CLS.JO', 'INL.JO', 'NED.JO', 'NPN.JO']
# Observations: prices=6,583, returns=600

# %%
pip install --user mitosheet
# Out:
# Requirement already satisfied: mitosheet in c:\users\mphep\appdata\roaming\python\python312\site-packages (0.2.39)
# Requirement already satisfied: jupyterlab~=4.0 in c:\programdata\anaconda3\lib\site-packages (from mitosheet) (4.2.5)
# Requirement already satisfied: pandas>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from mitosheet) (2.2.2)
# Requirement already satisfied: analytics-python in c:\users\mphep\appdata\roaming\python\python312\site-packages (from mitosheet) (1.4.post1)
# Requirement already satisfied: plotly<6.0.0,>=4.14.3 in c:\programdata\anaconda3\lib\site-packages (from mitosheet) (5.24.1)
# Requirement already satisfied: chardet>=3.0.4 in c:\programdata\anaconda3\lib\site-packages (from mitosheet) (4.0.0)
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\lib\site-packages (from mitosheet) (3.1.5)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from mitosheet) (24.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\mphep\appdata\roaming\python\python312\site-packages (from jupyterlab~=4.0->mitosheet) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (0.2.3)
# Requirement already satisfied: setuptools>=40.1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (75.1.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (6.4.1)
# Requirement already satisfied: traitlets in c:\programdata\anaconda3\lib\site-packages (from jupyterlab~=4.0->mitosheet) (5.14.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->mitosheet) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->mitosheet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->mitosheet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->mitosheet) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly<6.0.0,>=4.14.3->mitosheet) (8.2.3)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\programdata\anaconda3\lib\site-packages (from analytics-python->mitosheet) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from analytics-python->mitosheet) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\mphep\appdata\roaming\python\python312\site-packages (from analytics-python->mitosheet) (1.6)
# Requirement already satisfied: backoff==1.10.0 in c:\users\mphep\appdata\roaming\python\python312\site-packages (from analytics-python->mitosheet) (1.10.0)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl->mitosheet) (1.1.0)
# Requirement already satisfied: anyio in c:\users\mphep\appdata\roaming\python\python312\site-packages (from httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (1.0.2)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\mphep\appdata\roaming\python\python312\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (1.6.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (25.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab~=4.0->mitosheet) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core->jupyterlab~=4.0->mitosheet) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core->jupyterlab~=4.0->mitosheet) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\programdata\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (4.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.7->analytics-python->mitosheet) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.7->analytics-python->mitosheet) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab~=4.0->mitosheet) (4.11.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (21.2.0)
# Requirement already satisfied: backcall in c:\users\mphep\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.19.1)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0->mitosheet) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (4.1.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.16.2)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.8.3)
# Requirement already satisfied: fqdn in c:\users\mphep\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\mphep\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\programdata\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.1)
# Requirement already satisfied: uri-template in c:\users\mphep\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\mphep\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (24.11.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0->mitosheet) (0.2.2)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\programdata\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0->mitosheet) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
